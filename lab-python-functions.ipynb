# %% [markdown]
# # Lab | Functions

# %% [markdown]
# ## Exercise: Managing Customer Orders with Functions
#
# In the previous exercise, you improved the code for managing customer orders by using loops and flow control. Now, let's take it a step further and refactor the code by introducing functions.
#
# Follow the steps below to complete the exercise:
#
# 1. Define a function named `initialize_inventory` that takes `products` as a parameter. Inside the function, implement the code for initializing the inventory dictionary using a loop and user input.
#
# 2. Define a function named `get_customer_orders` that takes no parameters. Inside the function, implement the code for prompting the user to enter the product names using a loop. The function should return the `customer_orders` set.
#
# 3. Define a function named `update_inventory` that takes `customer_orders` and `inventory` as parameters. Inside the function, implement the code for updating the inventory dictionary based on the customer orders.
#
# 4. Define a function named `calculate_order_statistics` that takes `customer_orders` and `products` as parameters. Inside the function, implement the code for calculating the order statistics (total products ordered, and percentage of unique products ordered). The function should return these values.
#
# 5. Define a function named `print_order_statistics` that takes `order_statistics` as a parameter. Inside the function, implement the code for printing the order statistics.
#
# 6. Define a function named `print_updated_inventory` that takes `inventory` as a parameter. Inside the function, implement the code for printing the updated inventory.
#
# 7. Call the functions in the appropriate sequence to execute the program and manage customer orders.
#
# Hints for functions:
#
# - Consider the input parameters required for each function and their return values.
# - Utilize function parameters and return values to transfer data between functions.
# - Test your functions individually to ensure they work correctly.

# %%
#Exercise 1
inventory = {} 
products=["t-shirt", "mug", "hat", "book", "keychain"] #that takes products as a parameter
def initialize_inventory(products): #Define a function named initialize_inventory #Inside the function
    for product in products : # implement the code for initializing the inventory dictionary using a loop
        qty = int(input(f"How many {product} did you count :")) #and user input.
        inventory[product] = qty
    return qty

current_inventory =  initialize_inventory(products)
print(inventory)
# Out:
# How many t-shirt did you count : 5
# How many mug did you count : 6
# How many hat did you count : 7
# How many book did you count : 8
# How many keychain did you count : 9
# {'t-shirt': 5, 'mug': 6, 'hat': 7, 'book': 8, 'keychain': 9}

# %%
#Exercise 2
def get_customer_orders(): #Define a function named get_customer_orders that takes no parameters. 
    customer_orders = set()
    answer= "yes"

    while answer == "yes":
        article_added=(input("which article you want to order :").lower())#Inside the function, implement the code for prompting the user to enter the product names using a loop.
        customer_orders.add(article_added)
        answer = input("do you want to order an other article? : ").lower()
    return customer_orders   
customer_orders=get_customer_orders()
print(customer_orders)
type(customer_orders)
# Out:
# which article you want to order : hat
# do you want to order an other article? :  yes
# which article you want to order : book
# do you want to order an other article? :  yes
# which article you want to order : mug
# do you want to order an other article? :  no
# {'mug', 'book', 'hat'}
# set

# %%
#Exercise 5
def print_order_statistics(order_statistics): #Define a function named print_order_statistics that takes order_statistics as a parameter.
    print (f"total products ordered, percentage unique: {order_statistics}")
order_statistics = total_ordered, percent_unique
print_order_statistics(order_statistics)
# Out:
# total products ordered, percentage unique: (4, 80.0)

# %%
#Exercise 3
def update_inventory(customer_orders , inventory) :#Define a function named update_inventory that takes customer_orders and inventory as parameters.
    for product in customer_orders :# Inside the function, implement the code for updating the inventory dictionary based on the customer orders.
        if product in inventory and inventory[product]>0 :
            inventory[product] -= 1
        else :
            print(f"Oops, there is not {product} available in stock !") 
    return inventory
    
inventory_updated = update_inventory(customer_orders , inventory)
print(inventory_updated)  
type(inventory_updated)
# Out:
# {'t-shirt': 5, 'mug': 5, 'hat': 6, 'book': 7, 'keychain': 9}
# dict

# %%
#Exercise 6
def print_updated_inventory(inventory): #Define a function named print_updated_inventory that takes inventory as a parameter.
    print (f"actual inventory is: {inventory}")#Inside the function, implement the code for printing the updated inventory.
inventory = inventory_updated
print_updated_inventory(inventory)
# Out:
# actual inventory is: {'t-shirt': 5, 'mug': 5, 'hat': 6, 'book': 7, 'keychain': 9}

# %%
#Exercise 4
customer_orders_dict = {}
for article in customer_orders :
    customer_orders_dict[article]=1
def calculate_order_statistics(customer_orders_dict , products) : #Define a function named calculate_order_statistics that takes customer_orders and products as parameters.
    total_products_ordered = sum(customer_orders_dict.values())
    unique_products_ordered = len(set(customer_orders_dict.keys()))
    percentage_unique=(unique_products_ordered/len(products))*100      
    return total_products_ordered, percentage_unique


total_ordered, percent_unique = calculate_order_statistics(customer_orders_dict, products)
order_statistics = total_ordered, percent_unique
print (order_statistics)
print(f"total products ordered : {total_ordered}")
print(f"percentage unique : {percent_unique}%")
type(order_statistics)
    # Inside the function, implement the code for calculating the order statistics (total products ordered, and percentage of unique products ordered). The function should return these values.
# Out:
# (3, 60.0)
# total products ordered : 3
# percentage unique : 60.0%
# tuple
